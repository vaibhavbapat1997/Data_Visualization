# %%
import pandas as pd #importing the file here
df=pd.read_csv("height_gender.csv") #reading the file
male_height=df.loc[df["Gender"]=="Male"]

# %%
df
# Out:
#       Gender     Height
# 0       Male  73.847017
# 1       Male  68.781904
# 2       Male  74.110105
# 3       Male  71.730978
# 4       Male  69.881796
# ...      ...        ...
# 9995  Female  66.172652
# 9996  Female  67.067155
# 9997  Female  63.867992
# 9998  Female  69.034243
# 9999  Female  61.944246
#
# [10000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt #this is used to plot a histogram
plt.hist(male_height["Height"], bins=30, facecolor='red', edgecolor='black')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.title('Height of males')
plt.show()

# %%
#compare the mean and median
male_height.describe()
# Out:
#             Height
# count  5000.000000
# mean     69.026346
# std       2.863362
# min      58.406905
# 25%      67.174679
# 50%      69.027709
# 75%      70.988744
# max      78.998742

# %%
###Check for 1st deviation
one_std=male_height.loc[(male_height["Height"]< 71.889708) & (male_height["Height"]>66.16298400000001)]
print(len(one_std))

###Check for 2nd deviation
two_std=male_height.loc[(male_height["Height"]< 74.75307000000001) & (male_height["Height"]>63.29962200000001)]
print(len(two_std))

###Check for 3rd deviation
three_std=male_height.loc[(male_height["Height"]< 77.616432) & (male_height["Height"]>60.436260000000004)]
print(len(three_std))
# Out:
# 3447
# 4770
# 4985

# %%
df.describe()
# Out:
#              Height
# count  10000.000000
# mean      66.367560
# std        3.847528
# min       54.263133
# 25%       63.505620
# 50%       66.318070
# 75%       69.174262
# max       78.998742

# %%
#Class Exercise: Do it for females
female_height=df.loc[df["Gender"]=="Female"]
plt.hist(female_height["Height"], bins=30, facecolor='red', edgecolor='black')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.title('Height of females')
plt.show()

# %%
#compare the mean and median
female_height.describe()
# Out:
#             Height
# count  5000.000000
# mean     63.708774
# std       2.696284
# min      54.263133
# 25%      61.894441
# 50%      63.730924
# 75%      65.563565
# max      73.389586

# %%
###Check for 1st deviation
one_std=female_height.loc[(female_height["Height"]< 66.405058) & (female_height["Height"]>61.01249)]
print(len(one_std))

###Check for 2nd deviation
two_std=female_height.loc[(female_height["Height"]< 69.101342) & (female_height["Height"]>58.316206)]
print(len(two_std))

###Check for 3rd deviation
three_std=female_height.loc[(female_height["Height"]< 71.797626) & (female_height["Height"]>55.619922)]
print(len(three_std))
# Out:
# 3403
# 4766
# 4990

# %%
df_male=df.loc[df['Gender']=='Male']
df_female=df.loc[df['Gender']=='Female']

# %%
#Plot them both together
plt.hist(df_female["Height"], bins=10,facecolor='red',ec='black',alpha=0.5, label = 'female')
plt.hist(df_male["Height"], bins=10, facecolor='green',ec='black',alpha=0.5, label='male')
plt.legend()
plt.show()

# %%
#!pip install yfinance
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2020-09-17')
plt.figure(figsize=(10,10))
plt.plot(tsla_df['Open'])
# plt.plot(tsla_df['High'],label="High")
# plt.plot(tsla_df['Low'],label="Low")
# plt.plot(tsla_df['Close'],label="Close")
#create a label for x and y axes
plt.xlabel('Date',fontsize=14)
plt.ylabel('Stock price',fontsize=20)
#give the graph a title
plt.title('Tesla stocks',fontsize=30)

plt.legend(loc="upper left",fontsize=14)

plt.xticks(fontsize=20, rotation=90)
plt.yticks(fontsize=20, rotation=50)

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# No handles with labels found to put in legend.

# %%
###this is plotting google with tesla
###get google data, amc data, 
google_df=yf.download("GOOG", start="2019-01-01", end='2020-09-17')
plt.figure(figsize=(12,8))
plt.plot(tsla_df["Open"],label="Tesla plot",color="green")
plt.plot(google_df["Open"],label="Google plot",color="red")
plt.legend(fontsize=16, loc="upper left")
plt.xlabel("Date",fontsize=14)
plt.ylabel("Stock Price",fontsize=14)
plt.xticks(fontsize=16,rotation=50)
#plt.yticks([0, 300,600,900, 1200, 1500],fontsize=18)
plt.yticks(fontsize=18)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# The distplot represents the univariate distribution of data i.e. data distribution of a variable against the density distribution.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
tips=pd.read_csv("tips.csv")

import seaborn as sns #by convention we import  seaborn as sns
import matplotlib.pyplot as plt
#we will see different distribution plots
#try to see how different variables are distributed
sns.histplot(tips["total_bill"],bins=20,color="red",kde=True)
plt.xlabel("Bingo",fontsize=15)
plt.text(25,20,"Writing in sns", size='medium', color='green')
plt.xticks(rotation=90)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
'''this is using distplot'''
sns.distplot(tips["total_bill"],bins=20,color="red",hist_kws=dict(edgecolor="green", linewidth=2))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#simple scatter plots
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="day", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", size="day",sizes=(10, 1000), data=tips)

# %%
'''doing the regression plot'''
sns.regplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#lets say we want to compare two distributions
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
##also works with hue
sns.jointplot(x="total_bill",y="tip",data=tips, hue="sex")

# %%
#Add regression line
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")

# %%
#Replace the scatterplot with a joint histogram using hexagonal bins:
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")

# %%
#if you are feeling lazy
sns.pairplot(tips) #plots the distribution for all numerical columns

# %%
#passing the hue argument from a categorical column
sns.pairplot(tips, hue="sex")

# %%
#changing some colors
sns.pairplot(tips, hue="sex",palette="Set3")

# %%
#****************************************
#****************************************
"""Plotting the categorical variables"""
#****************************************
#****************************************
#plotting the bar plots
sns.countplot(x="sex",data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="smoker",data=tips,hue="day")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hue will produce data points with different colors. Hue can be used to group to multiple data variable and show the dependency of the passed data values are to be plotted.

# %%
###exercise: for height gender data do the boxplot
df_height_gender=pd.read_csv("height_gender.csv")
sns.boxplot(x="Gender",y="Height",data=df_height_gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Height'>

# %%
##bexercise: pokemon data do boxplots for HP, Attack, defense, and speed
df_pokemon=pd.read_csv("pokemon_data.csv")
df_pokemon=df_pokemon[['HP', 'Attack', 'Defense',  'Speed']]
sns.boxplot(data=df_pokemon)
# Out:
# <AxesSubplot:>

# %%
####MORE BOXPLOTSSS
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#using the hue
sns.boxplot(x="day",y="total_bill",data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#more categorical plots
sns.catplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
#********************************************************************
"""Matrix plots, also called as heatmaps"""
#********************************************************************
tc=tips.corr()
sns.heatmap(tc)
#****************************************************************
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
titanic=pd.read_csv("Titanic.csv")

import seaborn as sns
sns.pairplot(titanic)

sns.jointplot(x="Age",y="Fare",data=titanic)
sns.histplot(titanic["Fare"])
sns.boxplot(x="Pclass",y="Age",data=titanic)
sns.countplot(x="Sex",data=titanic)

tc=titanic.corr()
sns.heatmap(tc)
sns.relplot(x="Pclass", y="Fare", hue="Sex", data=titanic)
